# %%
# !pip install hide_code --user
# !jupyter nbextension install --sys-prefix --py hide_code
# !jupyter nbextension enable --sys-prefix --py hide_code
# !jupyter serverextension enable --sys-prefix --py hide_code
# Out:
# Requirement already satisfied: hide_code in /home/jupyter/.local/lib/python3.6/site-packages (0.5.5)
# Requirement already satisfied: pdfkit in /home/jupyter/.local/lib/python3.6/site-packages (from hide_code) (0.6.1)
# Requirement already satisfied: jupyter in /home/jupyter/.local/lib/python3.6/site-packages (from hide_code) (1.0.0)
# Requirement already satisfied: notebook>=5.1 in /opt/conda/lib/python3.6/site-packages (from hide_code) (5.7.2)
# Requirement already satisfied: nbconvert>=5.0 in /opt/conda/lib/python3.6/site-packages (from hide_code) (5.4.0)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.6/site-packages (from jupyter->hide_code) (5.1.0)
# Requirement already satisfied: qtconsole in /home/jupyter/.local/lib/python3.6/site-packages (from jupyter->hide_code) (4.7.7)
# Requirement already satisfied: ipywidgets in /home/jupyter/.local/lib/python3.6/site-packages (from jupyter->hide_code) (7.5.1)
# Requirement already satisfied: jupyter-console in /home/jupyter/.local/lib/python3.6/site-packages (from jupyter->hide_code) (6.2.0)
# Requirement already satisfied: traitlets>=4.2.1 in /opt/conda/lib/python3.6/site-packages (from notebook>=5.1->hide_code) (4.3.2)
# Requirement already satisfied: Send2Trash in /opt/conda/lib/python3.6/site-packages (from notebook>=5.1->hide_code) (1.5.0)
# Requirement already satisfied: terminado>=0.8.1 in /opt/conda/lib/python3.6/site-packages (from notebook>=5.1->hide_code) (0.8.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.6/site-packages (from notebook>=5.1->hide_code) (2.10)
# Requirement already satisfied: jupyter-core>=4.4.0 in /opt/conda/lib/python3.6/site-packages (from notebook>=5.1->hide_code) (4.4.0)
# Requirement already satisfied: tornado>=4 in /opt/conda/lib/python3.6/site-packages (from notebook>=5.1->hide_code) (5.1.1)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.6/site-packages (from notebook>=5.1->hide_code) (0.2.0)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.6/site-packages (from notebook>=5.1->hide_code) (0.5.0)
# Requirement already satisfied: jupyter-client>=5.2.0 in /opt/conda/lib/python3.6/site-packages (from notebook>=5.1->hide_code) (5.2.4)
# Requirement already satisfied: nbformat in /opt/conda/lib/python3.6/site-packages (from notebook>=5.1->hide_code) (4.4.0)
# Requirement already satisfied: pyzmq>=17 in /opt/conda/lib/python3.6/site-packages (from notebook>=5.1->hide_code) (17.1.2)
# Requirement already satisfied: mistune>=0.8.1 in /opt/conda/lib/python3.6/site-packages (from nbconvert>=5.0->hide_code) (0.8.4)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.6/site-packages (from nbconvert>=5.0->hide_code) (2.3.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/conda/lib/python3.6/site-packages (from nbconvert>=5.0->hide_code) (0.3)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.6/site-packages (from nbconvert>=5.0->hide_code) (3.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.6/site-packages (from nbconvert>=5.0->hide_code) (1.4.2)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.6/site-packages (from nbconvert>=5.0->hide_code) (0.4.2)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.6/site-packages (from nbconvert>=5.0->hide_code) (0.5.0)
# Requirement already satisfied: ipython>=5.0.0 in /opt/conda/lib/python3.6/site-packages (from ipykernel->jupyter->hide_code) (7.2.0)
# Requirement already satisfied: qtpy in /home/jupyter/.local/lib/python3.6/site-packages (from qtconsole->jupyter->hide_code) (1.9.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/jupyter/.local/lib/python3.6/site-packages (from ipywidgets->jupyter->hide_code) (3.5.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.6/site-packages (from jupyter-console->jupyter->hide_code) (2.0.8)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from traitlets>=4.2.1->notebook>=5.1->hide_code) (1.12.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.6/site-packages (from traitlets>=4.2.1->notebook>=5.1->hide_code) (4.3.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.6/site-packages (from jinja2->notebook>=5.1->hide_code) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/conda/lib/python3.6/site-packages (from jupyter-client>=5.2.0->notebook>=5.1->hide_code) (2.7.5)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/conda/lib/python3.6/site-packages (from nbformat->notebook>=5.1->hide_code) (3.0.0a3)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.6/site-packages (from bleach->nbconvert>=5.0->hide_code) (0.5.1)
# Requirement already satisfied: setuptools>=18.5 in /opt/conda/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel->jupyter->hide_code) (40.7.1)
# Requirement already satisfied: jedi>=0.10 in /opt/conda/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel->jupyter->hide_code) (0.13.2)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel->jupyter->hide_code) (0.7.5)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel->jupyter->hide_code) (0.1.0)
# Requirement already satisfied: pexpect in /opt/conda/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel->jupyter->hide_code) (4.6.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.6/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->hide_code) (0.1.7)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=5.1->hide_code) (18.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=5.1->hide_code) (0.14.9)
# Requirement already satisfied: parso>=0.3.0 in /opt/conda/lib/python3.6/site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel->jupyter->hide_code) (0.3.2)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.6/site-packages (from pexpect->ipython>=5.0.0->ipykernel->jupyter->hide_code) (0.6.0)
# Installing /home/jupyter/.local/lib/python3.6/site-packages/hide_code/ -> hide_code
# Making directory: /opt/conda/share/jupyter/nbextensions/hide_code/
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/hide_code_latexpdf_exporter.py -> /opt/conda/share/jupyter/nbextensions/hide_code/hide_code_latexpdf_exporter.py
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/utils.py -> /opt/conda/share/jupyter/nbextensions/hide_code/utils.py
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/LICENSE -> /opt/conda/share/jupyter/nbextensions/hide_code/LICENSE
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/__init__.py -> /opt/conda/share/jupyter/nbextensions/hide_code/__init__.py
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/auto-load.txt -> /opt/conda/share/jupyter/nbextensions/hide_code/auto-load.txt
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/hide_code_html_exporter.py -> /opt/conda/share/jupyter/nbextensions/hide_code/hide_code_html_exporter.py
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/auto-load-server-extension.txt -> /opt/conda/share/jupyter/nbextensions/hide_code/auto-load-server-extension.txt
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/hide_code.py -> /opt/conda/share/jupyter/nbextensions/hide_code/hide_code.py
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/hide_code_latex_exporter.py -> /opt/conda/share/jupyter/nbextensions/hide_code/hide_code_latex_exporter.py
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/hide_code_preprocessor.py -> /opt/conda/share/jupyter/nbextensions/hide_code/hide_code_preprocessor.py
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/hide_code.js -> /opt/conda/share/jupyter/nbextensions/hide_code/hide_code.js
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/hide_code_slides_exporter.py -> /opt/conda/share/jupyter/nbextensions/hide_code/hide_code_slides_exporter.py
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/hide_code_config.py -> /opt/conda/share/jupyter/nbextensions/hide_code/hide_code_config.py
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/hide_code_pdf_exporter.py -> /opt/conda/share/jupyter/nbextensions/hide_code/hide_code_pdf_exporter.py
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/hide_code_config.json -> /opt/conda/share/jupyter/nbextensions/hide_code/hide_code_config.json
# Making directory: /opt/conda/share/jupyter/nbextensions/hide_code/Templates
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/Templates/hide_code_article.tplx -> /opt/conda/share/jupyter/nbextensions/hide_code/Templates/hide_code_article.tplx
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/Templates/hide_code_basic.tpl -> /opt/conda/share/jupyter/nbextensions/hide_code/Templates/hide_code_basic.tpl
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/Templates/hide_code_slides.tpl -> /opt/conda/share/jupyter/nbextensions/hide_code/Templates/hide_code_slides.tpl
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/Templates/hide_code_base_style.tplx -> /opt/conda/share/jupyter/nbextensions/hide_code/Templates/hide_code_base_style.tplx
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/Templates/hide_code_full.tpl -> /opt/conda/share/jupyter/nbextensions/hide_code/Templates/hide_code_full.tpl
# Making directory: /opt/conda/share/jupyter/nbextensions/hide_code/__pycache__
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/__pycache__/hide_code_preprocessor.cpython-36.pyc -> /opt/conda/share/jupyter/nbextensions/hide_code/__pycache__/hide_code_preprocessor.cpython-36.pyc
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/__pycache__/hide_code_slides_exporter.cpython-36.pyc -> /opt/conda/share/jupyter/nbextensions/hide_code/__pycache__/hide_code_slides_exporter.cpython-36.pyc
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/__pycache__/__init__.cpython-36.pyc -> /opt/conda/share/jupyter/nbextensions/hide_code/__pycache__/__init__.cpython-36.pyc
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/__pycache__/hide_code_html_exporter.cpython-36.pyc -> /opt/conda/share/jupyter/nbextensions/hide_code/__pycache__/hide_code_html_exporter.cpython-36.pyc
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/__pycache__/hide_code_config.cpython-36.pyc -> /opt/conda/share/jupyter/nbextensions/hide_code/__pycache__/hide_code_config.cpython-36.pyc
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/__pycache__/utils.cpython-36.pyc -> /opt/conda/share/jupyter/nbextensions/hide_code/__pycache__/utils.cpython-36.pyc
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/__pycache__/hide_code.cpython-36.pyc -> /opt/conda/share/jupyter/nbextensions/hide_code/__pycache__/hide_code.cpython-36.pyc
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/__pycache__/hide_code_pdf_exporter.cpython-36.pyc -> /opt/conda/share/jupyter/nbextensions/hide_code/__pycache__/hide_code_pdf_exporter.cpython-36.pyc
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/__pycache__/hide_code_latex_exporter.cpython-36.pyc -> /opt/conda/share/jupyter/nbextensions/hide_code/__pycache__/hide_code_latex_exporter.cpython-36.pyc
# Copying: /home/jupyter/.local/lib/python3.6/site-packages/hide_code/__pycache__/hide_code_latexpdf_exporter.cpython-36.pyc -> /opt/conda/share/jupyter/nbextensions/hide_code/__pycache__/hide_code_latexpdf_exporter.cpython-36.pyc
# - Validating: OK
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable hide_code --py --sys-prefix
# Enabling notebook extension hide_code/hide_code...
#       - Validating: OK
# Enabling: hide_code
# - Writing config: /opt/conda/etc/jupyter
#     - Validating...
#       hide_code  OK
